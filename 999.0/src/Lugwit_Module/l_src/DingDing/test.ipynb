# %%
'AA+![测试](D:\\aa\\4.0.2.jpg)'
# Out:
# 'AA+![测试](D:\\aa\\4.0.2.jpg)'

# %% [markdown]
# #AA+
# [测试](file///:D:/aa/4.0.2.jpg)
# # 这是支持markdown的文本 \n## 标题2  \n* 列表1 \n![alt 啊](https://img.alicdn.com/tps/TB1XLjqNVXXXXc4XVXXXXXXXXXX-170-64.png)

# %% [markdown]
# P4V support for some [打开文档 S:/DataTrans/FQQ/新建DOC文档.doc](file:///S:/DataTrans/FQQ/新建DOC文档.doc)
