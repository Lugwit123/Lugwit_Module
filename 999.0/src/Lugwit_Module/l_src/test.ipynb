# %%
# %%time
for i in range(100000):
    import re,random,sys,os
# Out:
# CPU times: total: 31.2 ms
# Wall time: 48.8 ms

# %%
# %%time
for i in range(1000):
    import re,random,sys,os
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
